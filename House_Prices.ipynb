# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasFreitas98/Data-Science/blob/main/House_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e623acf7-6314-4177-b783-a546ba254d53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e623acf7-6314-4177-b783-a546ba254d53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'casas.csv': b'tamanho,ano,garagem,preco\n159.0,2003,2,208500\n117.0,1976,2,181500\n166.0,2001,2,223500\n160.0,1915,3,140000\n204.0,2000,3,250000\n127.0,1993,2,143000\n157.0,2004,2,307000\n194.0,1973,2,200000\n165.0,1931,2,129900\n100.0,1939,1,118000\n97.0,1965,1,129500\n216.0,2005,3,345000\n85.0,1962,1,144000\n139.0,2006,3,279500\n116.0,1960,1,157000\n79.0,1929,2,132000\n93.0,1970,2,149000\n120.0,1967,2,90000\n103.0,2004,2,159000\n124.0,1958,1,139000\n221.0,2005,3,325300\n103.0,1930,1,139400\n167.0,2002,2,230000\n98.0,1976,2,129900\n98.0,1968,1,154000\n149.0,2007,3,256300\n84.0,1951,2,134800\n158.0,2007,3,306000\n149.0,1957,1,207500\n48.0,1927,1,68500\n122.0,1920,1,40000\n114.0,1966,1,149350\n115.0,2007,2,179900\n158.0,1959,2,165500\n145.0,2005,2,277500\n228.0,2004,3,309000\n102.0,1994,2,145000\n120.0,1954,2,153000\n98.0,1953,1,109000\n107.0,1955,0,82000\n123.0,1965,2,160000\n123.0,1959,1,170000\n82.0,1983,2,144000\n87.0,1975,1,130250\n107.0,1959,1,141000\n163.0,2005,2,319900\n200.
# ...

# %%
import io
import pandas as pd

df = pd.read_csv(io.BytesIO(uploaded['casas.csv']))

# %%
df.head()
# Out:
#    tamanho   ano  garagem   preco
# 0    159.0  2003        2  208500
# 1    117.0  1976        2  181500
# 2    166.0  2001        2  223500
# 3    160.0  1915        3  140000
# 4    204.0  2000        3  250000

# %%
colunas = ['tamanho', 'preco']
df = df[colunas]

# %%
df.head()
# Out:
#    tamanho   preco
# 0    159.0  208500
# 1    117.0  181500
# 2    166.0  223500
# 3    160.0  140000
# 4    204.0  250000

# %%
x = df.drop('preco', axis=1)
y = df['preco']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=42)

# %%
x_train.head()
# Out:
#       tamanho
# 135     156.0
# 1452    100.0
# 762     144.0
# 932     177.0
# 435     154.0

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Out:
# array([1084.75077747])
